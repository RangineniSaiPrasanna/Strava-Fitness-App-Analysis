# %% [markdown]
# # **Strava Data Analysis**

# %% [markdown]
# <h1>Project Summary</h1>

# %% [markdown]
# This project focuses on analyzing Strava fitness data to uncover meaningful patterns in physical activity, health, and performance. It explores metrics such as steps, heart rate, sleep, and calorie burn across various time granularities—daily, hourly, and minute-level. Through exploratory data analysis, visualizations, and statistical modeling, the project identifies trends in workouts, recovery habits, and overall lifestyle. Techniques like clustering and time-series forecasting are used to personalize fitness insights, monitor progress, and detect anomalies. The insights are presented through intuitive dashboards and reports to support data-driven decision-making for improved health and performance.

# %% [markdown]
# <h3>1.Load DataSets and examine the columns</h3>

# %%
import pandas as pd
df = pd.read_csv('/home/prasanna/Downloads/strava_csvfiles/dailyActivity_merged.csv')
# Dataset Columns
print("csv file1 \n") 
print(df.columns)
print("\n")

df = pd.read_csv('/home/prasanna/Downloads/strava_csvfiles/dailyCalories_merged.csv')
# Dataset Columns
print("csv file2")
print("\n")
print(df.columns)
print("\n")

df = pd.read_csv('/home/prasanna/Downloads/strava_csvfiles/dailyIntensities_merged.csv')
# Dataset Columns
print("csv file3")
print("\n")
print(df.columns)
print("\n")

df = pd.read_csv('/home/prasanna/Downloads/strava_csvfiles/dailySteps_merged.csv')
# Dataset Columns
print("csv file4")
print("\n")
print(df.columns)
print("\n")

df = pd.read_csv('/home/prasanna/Downloads/strava_csvfiles/heartrate_seconds_merged.csv')
# Dataset Columns
print("csv file5")
print("\n")
print(df.columns)
print("\n")

df = pd.read_csv('/home/prasanna/Downloads/strava_csvfiles/hourlyCalories_merged.csv')
# Dataset Columns
print("csv file6")
print("\n")
print(df.columns)
print("\n")

df = pd.read_csv('/home/prasanna/Downloads/strava_csvfiles/hourlyIntensities_merged.csv')
# Dataset Columns
print("csv file7")
print("\n")
print(df.columns)
print("\n")

df = pd.read_csv('/home/prasanna/Downloads/strava_csvfiles/hourlySteps_merged.csv')
# Dataset Columns
print("csv file8")
print("\n")
print(df.columns)
print("\n")

df = pd.read_csv('/home/prasanna/Downloads/strava_csvfiles/minuteCaloriesNarrow_merged.csv')
# Dataset Columns
print("csv file9")
print("\n")
print(df.columns)
print("\n")

df = pd.read_csv('/home/prasanna/Downloads/strava_csvfiles/minuteCaloriesWide_merged.csv')
# Dataset Columns
print("csv file10")
print("\n")
print(df.columns)
print("\n")

df = pd.read_csv('/home/prasanna/Downloads/strava_csvfiles/minuteIntensitiesNarrow_merged.csv')
# Dataset Columns
print("csv file11")
print("\n")
print(df.columns)
print("\n")

df = pd.read_csv('/home/prasanna/Downloads/strava_csvfiles/minuteIntensitiesWide_merged.csv')
# Dataset Columns
print("csv file12")
print("\n")
print(df.columns)
print("\n")

df = pd.read_csv('/home/prasanna/Downloads/strava_csvfiles/minuteMETsNarrow_merged.csv')
# Dataset Columns
print("csv file13")
print("\n")
print(df.columns)
print("\n")

df = pd.read_csv('/home/prasanna/Downloads/strava_csvfiles/minuteSleep_merged.csv')
# Dataset Columns
print("csv file14")
print("\n")
print(df.columns)
print("\n")

df = pd.read_csv('/home/prasanna/Downloads/strava_csvfiles/minuteStepsNarrow_merged.csv')
# Dataset Columns
print("csv file15")
print("\n")
print(df.columns)
print("\n")

df = pd.read_csv('/home/prasanna/Downloads/strava_csvfiles/minuteStepsWide_merged.csv')
# Dataset Columns
print("csv file16")
print("\n")
print(df.columns)
print("\n")

df = pd.read_csv('/home/prasanna/Downloads/strava_csvfiles/sleepDay_merged.csv')
# Dataset Columns
print("csv file17")
print("\n")
print(df.columns)
print("\n")

df = pd.read_csv('/home/prasanna/Downloads/strava_csvfiles/weightLogInfo_merged.csv')
# Dataset Columns
print("csv file18")
print("\n")
print(df.columns)
print("\n")
# Out:
# csv file1
#
# Index(['Id', 'ActivityDate', 'TotalSteps', 'TotalDistance', 'TrackerDistance',
#        'LoggedActivitiesDistance', 'VeryActiveDistance',
#        'ModeratelyActiveDistance', 'LightActiveDistance',
#        'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',
#        'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories'],
#       dtype='object')
#
#
# csv file2
#
#
# Index(['Id', 'ActivityDay', 'Calories'], dtype='object')
#
#
# csv file3
#
#
# Index(['Id', 'ActivityDay', 'SedentaryMinutes', 'LightlyActiveMinutes',
#        'FairlyActiveMinutes', 'VeryActiveMinutes', 'SedentaryActiveDistance',
#        'LightActiveDistance', 'ModeratelyActiveDistance',
#        'VeryActiveDistance'],
#       dtype='object')
#
#
# csv file4
#
#
# Index(['Id', 'ActivityDay', 'StepTotal'], dtype='object')
#
#
# csv file5
#
#
# Index(['Id', 'Time', 'Value'], dtype='object')
#
#
# csv file6
#
#
# Index(['Id', 'ActivityHour', 'Calories'], dtype='object')
#
#
# csv file7
#
# ...

# %% [markdown]
# <h3>2.Load Key Data Sets</h3>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load all datasets
file_paths = {
    "df1": "/home/prasanna/Downloads/strava_csvfiles/dailyActivity_merged.csv",
    "df2": "/home/prasanna/Downloads/strava_csvfiles/dailyCalories_merged.csv",
    "df3": "/home/prasanna/Downloads/strava_csvfiles/dailyIntensities_merged.csv",
    "df4": "/home/prasanna/Downloads/strava_csvfiles/dailySteps_merged.csv",
    "df5": "/home/prasanna/Downloads/strava_csvfiles/heartrate_seconds_merged.csv",
    "df6": "/home/prasanna/Downloads/strava_csvfiles/hourlyCalories_merged.csv",
    "df7": "/home/prasanna/Downloads/strava_csvfiles/hourlyIntensities_merged.csv",
    "df8": "/home/prasanna/Downloads/strava_csvfiles/hourlySteps_merged.csv",
    "df9": "/home/prasanna/Downloads/strava_csvfiles/minuteCaloriesNarrow_merged.csv",
    "df10": "/home/prasanna/Downloads/strava_csvfiles/minuteCaloriesWide_merged.csv",
    "df11": "/home/prasanna/Downloads/strava_csvfiles/minuteIntensitiesNarrow_merged.csv",
    "df12": "/home/prasanna/Downloads/strava_csvfiles/minuteIntensitiesWide_merged.csv",
    "df13": "/home/prasanna/Downloads/strava_csvfiles/minuteMETsNarrow_merged.csv",
    "df14": "/home/prasanna/Downloads/strava_csvfiles/minuteSleep_merged.csv",
    "df15": "/home/prasanna/Downloads/strava_csvfiles/minuteStepsNarrow_merged.csv",
    "df16": "/home/prasanna/Downloads/strava_csvfiles/minuteStepsWide_merged.csv",
    "df17": "/home/prasanna/Downloads/strava_csvfiles/sleepDay_merged.csv",
    "df18": "/home/prasanna/Downloads/strava_csvfiles/weightLogInfo_merged.csv"
}

dfs = {name: pd.read_csv(path) for name, path in file_paths.items()}

# %% [markdown]
# <h3>3.Basic Info</h3>

# %%
print("Activity Data Info:")
print(activity.info(), "\n")

print("Missing Values:\n")
print(activity.isnull().sum())
# Out:
# Activity Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        940 non-null    int64
#  1   ActivityDate              940 non-null    object
#  2   TotalSteps                940 non-null    int64
#  3   TotalDistance             940 non-null    float64
#  4   TrackerDistance           940 non-null    float64
#  5   LoggedActivitiesDistance  940 non-null    float64
#  6   VeryActiveDistance        940 non-null    float64
#  7   ModeratelyActiveDistance  940 non-null    float64
#  8   LightActiveDistance       940 non-null    float64
#  9   SedentaryActiveDistance   940 non-null    float64
#  10  VeryActiveMinutes         940 non-null    int64
#  11  FairlyActiveMinutes       940 non-null    int64
#  12  LightlyActiveMinutes      940 non-null    int64
# ...

# %% [markdown]
# <h3>4.Descriptive Statistics</h3>

# %%
print("\nDescriptive Stats (Daily Activity):")
print(activity.describe())
# Out:
# Descriptive Stats (Daily Activity):
#                  Id    TotalSteps  TotalDistance  TrackerDistance  \
# count  9.400000e+02    940.000000     940.000000       940.000000
# mean   4.855407e+09   7637.910638       5.489702         5.475351
# std    2.424805e+09   5087.150742       3.924606         3.907276
# min    1.503960e+09      0.000000       0.000000         0.000000
# 25%    2.320127e+09   3789.750000       2.620000         2.620000
# 50%    4.445115e+09   7405.500000       5.245000         5.245000
# 75%    6.962181e+09  10727.000000       7.712500         7.710000
# max    8.877689e+09  36019.000000      28.030001        28.030001
#
#        LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# count                940.000000          940.000000                940.000000
# mean                   0.108171            1.502681                  0.567543
# std                    0.619897            2.658941                  0.883580
# ...

# %% [markdown]
# <h3>5.Data analysis</h3>

# %% [markdown]
# <h3>chart1:Correlation Heatmap</h3>

# %%
numeric_cols = ['TotalSteps', 'TotalDistance', 'VeryActiveDistance', 'ModeratelyActiveDistance',
                'LightActiveDistance', 'SedentaryActiveDistance', 'VeryActiveMinutes',
                'FairlyActiveMinutes', 'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories']

plt.figure(figsize=(10, 6))
sns.heatmap(activity[numeric_cols].corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap - Daily Activity Metrics")
plt.show()

# %% [markdown]
# Why did you pick the specific chart?
#
# A correlation heatmap is ideal for visualizing relationships between multiple numeric variables at once, showing the strength and direction of linear associations clearly and compactly.
#
# What is/are the insight(s) found from the chart?
#
# The heatmap reveals which daily activity metrics are strongly positively or negatively correlated, such as total steps being highly correlated with very active minutes and calories burned, indicating key activity drivers.
#
# Will the gained insights help create a positive business impact?
#
# Yes, these insights can guide personalized fitness recommendations and product features by highlighting which activity metrics to focus on for improving user health and engagement.

# %% [markdown]
# <h3>chart2:Daily Activity: Total Steps Over Time</h3>

# %%
plt.figure(figsize=(12, 6))
plt.plot(dfs["df1"]['ActivityDate'], dfs["df1"]['TotalSteps'], marker='o', linestyle='-')
plt.title('Total Steps Over Time (Daily Activity)')
plt.xlabel('Activity Date')
plt.ylabel('Total Steps')
plt.xticks(rotation=45)
plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# Why did you pick the specific chart?
#
# A line plot is perfect for showing trends over time, allowing us to observe how total steps change day by day and identify patterns or fluctuations clearly.
#
# What is/are the insight(s) found from the chart?
#
# The chart shows daily variations in total steps, highlighting periods of increased or decreased activity which might correspond to weekends, holidays, or lifestyle changes.
#
# Will the gained insights help create a positive business impact?
#
# Yes, tracking step trends over time helps in designing targeted health interventions or fitness challenges to boost user motivation and activity levels consistently.

# %% [markdown]
# <h3>chart3:Daily Calories: Average Calories Burned by Day</h3>

# %%
avg_calories = dfs["df2"].groupby('ActivityDay')['Calories'].mean()
plt.figure(figsize=(10, 5))
avg_calories.plot(kind='bar', color='skyblue')
plt.title('Average Calories Burned by Day')
plt.xlabel('Activity Day')
plt.ylabel('Average Calories')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# Why did you pick the specific chart?
#
# A bar chart effectively compares average calories burned across different days of the week, making it easy to see which days have higher or lower calorie burn.
#
# What is/are the insight(s) found from the chart?
#
# The chart reveals variation in average calories burned by day, which may reflect differences in user activity patterns throughout the week, such as higher calories burned on weekends or weekdays.
#
# Will the gained insights help create a positive business impact?
#
# Yes, understanding daily calorie burn trends can help tailor personalized workout or nutrition plans and schedule promotional campaigns aligned with users’ peak activity days.

# %% [markdown]
# <h3>chart4:Daily Intensities: Distribution of VeryActiveMinutes</h3>

# %%
plt.figure(figsize=(10, 5))
plt.hist(dfs["df3"]['VeryActiveMinutes'], bins=30, color='lightgreen', edgecolor='black')
plt.title('Distribution of Very Active Minutes (Daily Intensities)')
plt.xlabel('Very Active Minutes')
plt.ylabel('Frequency')
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# Why did you pick the specific chart?
#
# A histogram is ideal for showing the distribution of a single continuous variable—in this case, the number of very active minutes—by illustrating how frequently different ranges occur.
#
# What is/are the insight(s) found from the chart?
#
# The histogram reveals how users’ very active minutes are spread out, highlighting whether most users have low, moderate, or high activity intensity on a daily basis.
#
# Will the gained insights help create a positive business impact?
#
# Yes, understanding the distribution of activity intensity helps in designing targeted fitness programs and identifying user segments that may benefit from increased motivation or support.

# %% [markdown]
# <h3>chart5:Daily Steps: StepTotal over ActivityDay</h3>

# %%
plt.figure(figsize=(12, 6))
plt.plot(dfs["df4"]['ActivityDay'], dfs["df4"]['StepTotal'], marker='o', linestyle='-', color='orange')
plt.title('Total Steps Over Time (Daily Steps)')
plt.xlabel('Activity Day')
plt.ylabel('Step Total')
plt.xticks(rotation=45)
plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# Why did you pick the specific chart?
#
# A line plot is well-suited to visualize changes in total daily steps over time, allowing easy identification of trends, fluctuations, and patterns across days.
#
# What is/are the insight(s) found from the chart?
#
# The chart shows how total daily steps vary, helping spot periods of increased or decreased activity that might correspond to lifestyle factors or external influences.
#
# Will the gained insights help create a positive business impact?
#
# Yes, analyzing step trends over time enables personalized goal setting and can inform engagement strategies to encourage consistent physical activity among users.

# %% [markdown]
# <h3>chart6:Heart Rate: Time series plot of heart rate values</h3>

# %%
plt.figure(figsize=(12, 6))
plt.plot(pd.to_datetime(dfs["df5"]['Time']), dfs["df5"]['Value'], color='red')
plt.title('Heart Rate Over Time')
plt.xlabel('Time')
plt.ylabel('Heart Rate Value')
plt.xticks(rotation=45)
plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# Why did you pick the specific chart?
#
# A line plot is ideal for visualizing how heart rate changes continuously over time, allowing us to observe trends, spikes, or irregularities in heart rate data.
#
# What is/are the insight(s) found from the chart?
#
# The chart reveals fluctuations in heart rate, potentially indicating periods of activity, rest, or stress, and helps identify patterns or anomalies in user heart health.
#
# Will the gained insights help create a positive business impact?
#
# Yes, monitoring heart rate trends supports early detection of health issues and enables personalized fitness or wellness recommendations to improve user outcomes.

# %% [markdown]
# <h3>chart7:Hourly Calories: Average Calories Burned by Hour</h3>

# %%
avg_hourly_calories = dfs["df6"].groupby('ActivityHour')['Calories'].mean()
plt.figure(figsize=(10, 5))
avg_hourly_calories.plot(kind='bar', color='purple')
plt.title('Average Hourly Calories Burned')
plt.xlabel('Activity Hour')
plt.ylabel('Average Calories')
plt.xticks(rotation=0)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# Why did you pick the specific chart?
#
# A bar chart clearly compares average calories burned across each hour of the day, making it easy to identify periods of higher or lower calorie expenditure.
#
# What is/are the insight(s) found from the chart?
#
# The chart shows how calories burned fluctuate by hour, highlighting peak activity times which could correspond to exercise routines or daily habits.
#
# Will the gained insights help create a positive business impact?
#
# Yes, these insights can help optimize workout scheduling, promote targeted activity reminders, and improve personalized fitness coaching for users.

# %% [markdown]
# <h3>chart8: Hourly Intensities: Total and Average Intensity by Hour (line plot)</h3>

# %%
plt.figure(figsize=(12, 6))
plt.plot(dfs["df7"]['ActivityHour'], dfs["df7"]['TotalIntensity'], label='Total Intensity', color='blue')
plt.plot(dfs["df7"]['ActivityHour'], dfs["df7"]['AverageIntensity'], label='Average Intensity', color='green')
plt.title('Total and Average Intensity by Hour')
plt.xlabel('Activity Hour')
plt.ylabel('Intensity')
plt.legend()
plt.xticks(rotation=45)
plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# Why did you pick the specific chart?
#
# A dual-line plot effectively compares two related metrics—Total Intensity and Average Intensity—across hours, helping visualize their trends and relationships simultaneously.
#
# What is/are the insight(s) found from the chart?
#
# The chart reveals how both total and average activity intensity vary throughout the day, highlighting peak periods and differences between overall volume and intensity per unit.
#
# Will the gained insights help create a positive business impact?
#
# Yes, understanding hourly intensity patterns can optimize activity recommendations and tailor fitness programs to match user energy cycles and habits.

# %% [markdown]
# <h3>chart9:Hourly Steps: StepTotal by Hour</h3>

# %%
plt.figure(figsize=(12, 6))
plt.plot(dfs["df8"]['ActivityHour'], dfs["df8"]['StepTotal'], marker='o', linestyle='-', color='brown')
plt.title('Step Total by Hour')
plt.xlabel('Activity Hour')
plt.ylabel('Step Total')
plt.show()

# %% [markdown]
# Why did you pick the specific chart?
#
# A line plot is perfect for visualizing how step totals change throughout the day, allowing us to easily see hourly activity patterns.
#
# What is/are the insight(s) found from the chart?
#
# The chart highlights peak hours when users are most active, showing how step counts vary during the day and identifying potential times for targeted engagement or challenges.
#
# Will the gained insights help create a positive business impact?
#
# Yes, understanding hourly step patterns can help design better user prompts, optimize fitness goals, and improve personalized activity tracking features.

# %% [markdown]
# <h3>chart10:Minute Calories Wide: Calories by hour minute columns heatmap</h3>

# %%
import seaborn as sns
plt.figure(figsize=(14, 8))
calorie_cols = [col for col in dfs["df10"].columns if col.startswith('Calories')]
calorie_data = dfs["df10"][calorie_cols].astype(float)
sns.heatmap(calorie_data.transpose(), cmap='YlOrRd', cbar_kws={'label': 'Calories'})
plt.title('Calories Burned Per Minute (Wide Format)')
plt.xlabel('Sample Index')
plt.ylabel('Minute of the Hour')
plt.tight_layout()
plt.show()

# %% [markdown]
# Why did you pick the specific chart?
#
# A heatmap is ideal for visualizing calories burned per minute across many samples, highlighting patterns and intensity variations over time in a compact and intuitive way.
#
# What is/are the insight(s) found from the chart?
#
# The heatmap reveals periods with consistently higher or lower calorie burn rates within the hour, helping identify typical active and rest phases throughout the sampled periods.
#
# Will the gained insights help create a positive business impact?
#
# Yes, these insights can guide personalized coaching, optimize workout timing, and improve the design of activity-tracking features that adapt to users’ minute-level intensity fluctuations.

# %% [markdown]
# <h3>chart11:Minute Intensities Narrow: Intensity over ActivityMinute (line)</h3>

# %%
plt.figure(figsize=(12, 6))
plt.plot(
    pd.to_datetime(dfs["df11"]['ActivityMinute'], format="%m/%d/%Y %I:%M:%S %p"),
    dfs["df11"]['Intensity'],
    color='darkviolet'
)
plt.title('Intensity by Minute (Narrow)')
plt.xlabel('Activity Minute')
plt.ylabel('Intensity')
plt.show()

# %% [markdown]
# Why did you pick the specific chart?
#
# A line plot is perfect for showing how intensity changes minute-by-minute, revealing fine-grained temporal patterns in activity levels.
#
# What is/are the insight(s) found from the chart?
#
# The plot shows fluctuations in activity intensity at a very detailed timescale, helping identify bursts of high or low activity and their timing throughout the day.
#
# Will the gained insights help create a positive business impact?
#
# Yes, minute-level insights enable highly personalized fitness feedback and can inform real-time interventions to keep users motivated and active.

# %% [markdown]
# <h3>chart12:Minute Intensities Wide: Intensity heatmap per minute within hour</h3>

# %%
plt.figure(figsize=(14, 8))
intensity_cols = [col for col in dfs["df12"].columns if col.startswith('Intensity')]
intensity_data = dfs["df12"][intensity_cols].astype(float)
sns.heatmap(intensity_data.transpose(), cmap='coolwarm', cbar_kws={'label': 'Intensity'})
plt.title('Intensity Per Minute (Wide Format)')
plt.xlabel('Sample Index')
plt.ylabel('Minute of the Hour')
plt.tight_layout()
plt.show()

# %% [markdown]
# Why did you pick the specific chart?
#
# A heatmap effectively visualizes intensity values per minute across multiple samples, highlighting temporal patterns and variations in activity intensity throughout each hour.
#
# What is/are the insight(s) found from the chart?
#
# The heatmap uncovers periods with higher or lower intensity levels within the hour, showing consistent activity bursts and rest phases across samples.
#
# Will the gained insights help create a positive business impact?
#
# Yes, these detailed intensity patterns can inform personalized workout plans and real-time activity monitoring, enhancing user engagement and fitness outcomes.

# %% [markdown]
# <h3>chart13: Minute METs Narrow: METs over ActivityMinute (line plot)</h3>

# %%
plt.figure(figsize=(12, 6))
plt.plot(
    pd.to_datetime(dfs["df13"]['ActivityMinute'], format="%m/%d/%Y %I:%M:%S %p"),
    dfs["df13"]['METs'],
    color='darkgreen'
)
plt.title('METs by Minute')
plt.xlabel('Activity Minute')
plt.ylabel('METs')
plt.show()

# %% [markdown]
# Why did you pick the specific chart?
#
# A line plot is ideal for tracking METs (Metabolic Equivalent of Task) over time at minute-level granularity, allowing clear visualization of changes in physical activity intensity.
#
# What is/are the insight(s) found from the chart?
#
# The chart reveals fluctuations in METs throughout the day, identifying periods of higher energy expenditure and activity intensity.
#
# Will the gained insights help create a positive business impact?
#
# Yes, understanding minute-by-minute METs variations can support personalized fitness coaching and optimize activity recommendations for better health outcomes.

# %% [markdown]
# <h3>chart14:Minute Sleep: value over date (line plot)</h3>

# %%
plt.figure(figsize=(12, 6))
plt.plot(pd.to_datetime(dfs["df14"]['date']), dfs["df14"]['value'], color='darkorange')
plt.title('Sleep Values Over Time (MinuteSleep)')
plt.xlabel('Date')
plt.ylabel('Value')
plt.xticks(rotation=45)
plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# Why did you pick the specific chart?
#
# A line plot is great for visualizing trends in sleep metrics over time, helping track changes and patterns in minute-level sleep data across dates.
#
# What is/are the insight(s) found from the chart?
#
# The chart shows fluctuations in sleep values over days, highlighting periods of better or poorer sleep which may relate to lifestyle or external factors.
#
# Will the gained insights help create a positive business impact?
#
# Yes, monitoring sleep trends can inform personalized recommendations to improve sleep quality and overall wellness, enhancing user satisfaction and health outcomes.

# %% [markdown]
# <h3>chart15:Minute Steps Narrow: Steps over ActivityMinute (line plot)</h3>

# %%
plt.figure(figsize=(12, 6))
plt.plot(
    pd.to_datetime(dfs["df15"]['ActivityMinute'], format="%m/%d/%Y %I:%M:%S %p"),
    dfs["df15"]['Steps'],
    color='navy'
)
plt.title('Steps by Minute (Narrow)')
plt.xlabel('Activity Minute')
plt.ylabel('Steps')
plt.show()

# %% [markdown]
# Why did you pick the specific chart?
#
# A line plot is ideal for showing detailed minute-by-minute step counts, revealing fine temporal patterns in user activity.
#
# What is/are the insight(s) found from the chart?
#
# The plot shows bursts of steps throughout the day, highlighting active versus inactive periods at a very granular level.
#
# Will the gained insights help create a positive business impact?
#
# Yes, minute-level step data can drive personalized activity prompts and support behavior change strategies to boost user engagement and fitness.

# %% [markdown]
# <h3>chart16: Minute Steps Wide: Steps heatmap per minute within hour</h3>

# %%
plt.figure(figsize=(14, 8))
steps_cols = [col for col in dfs["df16"].columns if col.startswith('Steps')]
steps_data = dfs["df16"][steps_cols].astype(float)
sns.heatmap(steps_data.transpose(), cmap='Blues', cbar_kws={'label': 'Steps'})
plt.title('Steps Per Minute (Wide Format)')
plt.xlabel('Sample Index')
plt.ylabel('Minute of the Hour')
plt.tight_layout()
plt.show()

# %% [markdown]
# Why did you pick the specific chart?
#
# A heatmap is an excellent way to visualize steps taken per minute across multiple samples, showing patterns of activity intensity over time in an easy-to-interpret format.
#
# What is/are the insight(s) found from the chart?
#
# The heatmap highlights periods with higher or lower step counts, revealing consistent activity bursts and quieter moments within each hour across the dataset.
#
# Will the gained insights help create a positive business impact?
#
# Yes, understanding minute-level step patterns can help optimize activity recommendations, personalize fitness coaching, and enhance user motivation and retention.

# %% [markdown]
# <h3>chart17:Sleep Day: Box plot for Total Minutes Asleep</h3>

# %%
plt.figure(figsize=(10, 5))
plt.boxplot(dfs["df17"]['TotalMinutesAsleep'].dropna(), vert=False)
plt.title('Box Plot of Total Minutes Asleep')
plt.xlabel('Total Minutes Asleep')
plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# Why did you pick the specific chart?
#
# A box plot effectively summarizes the distribution of total minutes asleep, showing the median, quartiles, and potential outliers in a compact visual.
#
# What is/are the insight(s) found from the chart?
#
# The plot reveals the typical range of sleep duration, central tendency, and variability, and helps identify unusually short or long sleep episodes.
#
# Will the gained insights help create a positive business impact?
#
# Yes, understanding sleep duration patterns can guide personalized sleep improvement recommendations and support health monitoring initiatives.

# %% [markdown]
# <h3>chart18:Weight Log Info: WeightKg distribution histogram</h3>

# %%
plt.figure(figsize=(10, 5))
plt.hist(dfs["df18"]['WeightKg'].dropna(), bins=30, color='coral', edgecolor='black')
plt.title('Distribution of Weight in Kg')
plt.xlabel('Weight (Kg)')
plt.ylabel('Frequency')
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# Why did you pick the specific chart?
#
# A histogram is ideal for visualizing the distribution of weight values, showing how frequently different weight ranges occur in the dataset.
#
# What is/are the insight(s) found from the chart?
#
# The histogram reveals the spread and concentration of user weights, indicating common weight ranges and potential outliers.
#
# Will the gained insights help create a positive business impact?
#
# Yes, understanding weight distribution can help tailor health and fitness programs to user demographics and identify target groups for personalized interventions.

# %% [markdown]
# <h1>Combined Data analysis</h1>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load individual datasets relevant for combination analysis
df_activity = pd.read_csv('/home/prasanna/Downloads/strava_csvfiles/dailyActivity_merged.csv')
df_calories = pd.read_csv('/home/prasanna/Downloads/strava_csvfiles/dailyCalories_merged.csv')
df_intensities = pd.read_csv('/home/prasanna/Downloads/strava_csvfiles/dailyIntensities_merged.csv')
df_steps = pd.read_csv('/home/prasanna/Downloads/strava_csvfiles/dailySteps_merged.csv')
df_sleep = pd.read_csv('/home/prasanna/Downloads/strava_csvfiles/sleepDay_merged.csv')
df_weight = pd.read_csv('/home/prasanna/Downloads/strava_csvfiles/weightLogInfo_merged.csv')
df_heartrate = pd.read_csv('/home/prasanna/Downloads/strava_csvfiles/heartrate_seconds_merged.csv')

# Convert date columns to datetime with explicit format
df_sleep['SleepDay'] = pd.to_datetime(df_sleep['SleepDay'], format="%m/%d/%Y %I:%M:%S %p")
df_weight['Date'] = pd.to_datetime(df_weight['Date'], format="%m/%d/%Y %I:%M:%S %p")
df_heartrate['Time'] = pd.to_datetime(df_heartrate['Time'])

# Convert activity-related dates
df_activity['ActivityDate'] = pd.to_datetime(df_activity['ActivityDate'])
df_calories['ActivityDay'] = pd.to_datetime(df_calories['ActivityDay'])
df_intensities['ActivityDay'] = pd.to_datetime(df_intensities['ActivityDay'])
df_steps['ActivityDay'] = pd.to_datetime(df_steps['ActivityDay'])

# Merge datasets
df_daily = df_activity.merge(df_calories, left_on=['Id', 'ActivityDate'], right_on=['Id', 'ActivityDay'], how='inner', suffixes=('_act', '_cal'))
df_daily = df_daily.merge(df_intensities, on=['Id', 'ActivityDay'], how='inner')
df_daily = df_daily.merge(df_steps, on=['Id', 'ActivityDay'], how='inner', suffixes=('', '_steps'))

print("Combined daily data shape:", df_daily.shape)
print(df_daily.head())
# Out:
# Combined daily data shape: (940, 26)
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366   2016-04-12       13162           8.50             8.50
# 1  1503960366   2016-04-13       10735           6.97             6.97
# 2  1503960366   2016-04-14       10460           6.74             6.74
# 3  1503960366   2016-04-15        9762           6.28             6.28
# 4  1503960366   2016-04-16       12669           8.16             8.16
#
#    LoggedActivitiesDistance  VeryActiveDistance_x  ModeratelyActiveDistance_x  \
# 0                       0.0                  1.88                        0.55
# 1                       0.0                  1.57                        0.69
# 2                       0.0                  2.44                        0.40
# 3                       0.0                  2.14                        1.26
# 4                       0.0                  2.71                        0.41
#
# ...

# %% [markdown]
# <h3>Visualization 1: Scatter plot of Total Steps vs Calories (combined dataset)</h3>

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(
    data=df_daily,
    x='TotalSteps',
    y='Calories_act',
    hue='VeryActiveMinutes_x', 
    palette='viridis',
    alpha=0.7
)
plt.title('Total Steps vs Calories Burned (Colored by Very Active Minutes)')
plt.xlabel('Total Steps')
plt.ylabel('Calories')
plt.legend(title='Very Active Minutes')
plt.grid(True)
plt.show()

# %% [markdown]
# Why did you pick the specific chart?
#
# A scatter plot is great for exploring the relationship between two continuous variables—here, total steps and calories burned—while adding color to represent a third variable (Very Active Minutes) to reveal multidimensional patterns.
#
# What is/are the insight(s) found from the chart?
#
# The plot shows a positive correlation between steps and calories burned, with color intensity indicating that more very active minutes tend to correspond to higher calories burned, highlighting the impact of activity intensity.
#
# Will the gained insights help create a positive business impact?
#
# Yes, this insight can help tailor personalized fitness goals, motivate users by linking activity to calorie expenditure, and optimize health tracking features.

# %% [markdown]
# <h3>Visualization 2: Correlation heatmap of numeric columns in combined daily data</h3>

# %%
numeric_cols = [
    'TotalSteps', 
    'Calories_act', 
    'SedentaryMinutes_x', 
    'LightlyActiveMinutes_x', 
    'FairlyActiveMinutes_x', 
    'VeryActiveMinutes_x', 
    'StepTotal'
]

plt.figure(figsize=(10, 8))
sns.heatmap(df_daily[numeric_cols].corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap of Daily Activity Metrics')
plt.tight_layout()
plt.show()

# %% [markdown]
# Why did you pick the specific chart?
#
# A correlation heatmap clearly displays the strength and direction of relationships between multiple numeric variables, helping identify which activity metrics move together.
#
# What is/are the insight(s) found from the chart?
#
# The heatmap reveals strong positive correlations between steps, active minutes, and calories burned, while sedentary minutes typically show negative correlations with active metrics, highlighting the interplay of activity levels.
#
# Will the gained insights help create a positive business impact?
#
# Yes, understanding these correlations can guide feature prioritization in fitness apps, enhance personalized recommendations, and optimize interventions to improve user health outcomes.

# %% [markdown]
# <h3>Visualization 3: Sleep vs activity calories (merge sleep with daily calories on Id and date)</h3>

# %%
df_sleep_cal = df_sleep.merge(df_calories, left_on=['Id', 'SleepDay'], right_on=['Id', 'ActivityDay'], how='inner')
plt.figure(figsize=(10,6))
sns.scatterplot(data=df_sleep_cal, x='TotalMinutesAsleep', y='Calories')
plt.title('Total Minutes Asleep vs Calories Burned')
plt.xlabel('Total Minutes Asleep')
plt.ylabel('Calories Burned')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Why did you pick the specific chart?
#
# A scatter plot effectively visualizes the relationship between total minutes asleep and calories burned, showing how sleep duration might influence daily energy expenditure.
#
# What is/are the insight(s) found from the chart?
#
# The plot suggests potential correlations or trends between sleep duration and calorie burn, possibly indicating that longer or better sleep supports higher energy output.
#
# Will the gained insights help create a positive business impact?
#
# Yes, understanding the link between sleep and calories burned can inform holistic health recommendations, integrating sleep hygiene with fitness planning for better user outcomes.

# %% [markdown]
# <h3>Visualization 4:Heart rate time series for one user example (Id)</h3>

# %%
example_user = df_heartrate['Id'].iloc[0]
hr_user = df_heartrate[df_heartrate['Id'] == example_user].copy()
plt.figure(figsize=(14,6))
plt.plot(hr_user['Time'], hr_user['Value'], color='red')
plt.title(f'Heart Rate Over Time for User {example_user}')
plt.xlabel('Time')
plt.ylabel('Heart Rate')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Why did you pick the specific chart?
#
# A line plot is perfect for displaying continuous heart rate data over time for an individual user, capturing fluctuations and trends in cardiovascular activity.
#
# What is/are the insight(s) found from the chart?
#
# The plot reveals patterns of heart rate variation throughout the recorded period, potentially highlighting periods of rest, activity, or stress for the user.
#
# Will the gained insights help create a positive business impact?
#
# Yes, monitoring heart rate trends at the individual level can enhance personalized health tracking, early detection of anomalies, and tailored wellness recommendations.

# %% [markdown]
# <h3>Visualization 5: Average daily steps and calories by user (bar plot)</h3>

# %%
df_user_summary = df_daily.groupby('Id').agg({'TotalSteps':'mean', 'Calories_act':'mean'}).reset_index()
df_user_summary_sorted = df_user_summary.sort_values('TotalSteps', ascending=False).head(15)
plt.figure(figsize=(12,6))
sns.barplot(data=df_user_summary_sorted.melt(id_vars='Id'), x='Id', y='value', hue='variable')
plt.title('Mean Daily Steps and Calories by User (Top 15)')
plt.xlabel('User Id')
plt.ylabel('Average Value')
plt.legend(title='Metric')
plt.show()

# %% [markdown]
# Why did you pick the specific chart?
#
# A grouped bar plot effectively compares multiple metrics (mean daily steps and calories burned) side-by-side for each user, making it easy to spot patterns and differences across top-performing users.
#
# What is/are the insight(s) found from the chart?
#
# The chart shows which users tend to have higher average physical activity and energy expenditure, revealing the relationship between steps taken and calories burned among the top 15 users.
#
# Will the gained insights help create a positive business impact?
#
# Yes, identifying top active users helps in targeting personalized engagement strategies, benchmarking user performance, and designing tailored fitness challenges or rewards.

# %% [markdown]
# <h3>conclusion</h3>

# %% [markdown]
# This project explored diverse Strava datasets to reveal meaningful patterns in daily activity, calories burned, sleep quality, heart rate, and weight changes. The multi-level analysis showed how activity intensity fluctuates throughout the day and how sleep impacts overall health. These insights provide valuable guidance for creating personalized fitness and wellness strategies. By combining various data types, the study offers a holistic view of users’ lifestyles. Overall, it demonstrates the power of data-driven approaches to improve health and wellbeing.

# %% [markdown]
# <h1>Successfully Completed Data Analysis on Strava Fitness app</h1>
